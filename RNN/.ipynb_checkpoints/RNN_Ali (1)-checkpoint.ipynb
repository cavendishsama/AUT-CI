# %% [markdown]
# # Importin Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import json
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading The Dataset

# %%
def seq_data(data_f,window_length=100, time_shift=0):

    # Creates a list of 168 lists for battery_voltage
    lst_bv = [[] for _ in range(len(data_f.T))]
    # Creates a list of 168 lists for next_voltage
    lst_nv = [[] for _ in range(len(data_f.T))]
    # A list for capacity
    capacity = []

    for cycle in data_f.loc['Capacity']:
        capacity.append(cycle[0])

    for cycle_ind, cycle in enumerate(data_f.loc['voltage_battery']):
        for voltage_ind in range(len(cycle) - window_length - time_shift):

            if voltage_ind == 0:
                lst_bv[cycle_ind].append(cycle[voltage_ind: (voltage_ind + window_length)])    # 0 to 99      # 1 to 100
                lst_nv[cycle_ind].append(cycle[voltage_ind + window_length])                   # 100          # 101
            else:
                lst_bv[cycle_ind].append(cycle[voltage_ind + time_shift: (voltage_ind + window_length + time_shift)])    # 2 to 101
                lst_nv[cycle_ind].append(cycle[voltage_ind + window_length + time_shift])                                # 102

    # Nested List Comprehension for flattening lst_bv and lst_nv
    __lst_bv = [vol for sub_l in lst_bv for vol in sub_l]
    __lst_nv = [n_vol for sub_l in lst_nv for n_vol in sub_l]

    battery_voltage = np.array(__lst_bv)
    next_value = np.array(__lst_nv)
    capacity = np.array(capacity)

    battery_voltage = battery_voltage[...,np.newaxis]
    next_value = next_value[...,np.newaxis]
    capacity = capacity[...,np.newaxis]
    # print(battery_voltage.shape)
    # print(next_value.shape)
    # print(capacity.shape)

    return battery_voltage, next_value, capacity

# %%
data_f = pd.read_json('./assets/Nasa_LiB_B5_discharge.json')
window_length = 100
battery_voltage, next_value, capacity = seq_data(data_f,window_length=window_length, time_shift=0)
window_length = 1
print(battery_voltage.shape)
print(next_value.shape)
print(capacity.shape)
# Out:
# (33485, 100, 1)
# (33485, 1)
# (168, 1)

# %%
train_seq, test_seq, y_train, y_test = train_test_split(battery_voltage, next_value, test_size=0.25)

# %%
train_seq = train_seq[...,np.newaxis]
# train_seq = train_seq[:,np.newaxis]
y_train = y_train[...,np.newaxis]

# %%
data_f.T
# Out:
#     amb_temp              date_time  \
# 1         24  02 Apr 2008, 15:25:41
# 3         24  02 Apr 2008, 19:43:48
# 5         24  03 Apr 2008, 00:01:06
# 7         24  03 Apr 2008, 04:16:37
# 9         24  03 Apr 2008, 08:33:25
# ..       ...                    ...
# 599       24  26 May 2008, 10:44:38
# 603       24  26 May 2008, 15:30:43
# 607       24  26 May 2008, 20:21:04
# 611       24  27 May 2008, 15:52:41
# 613       24  27 May 2008, 20:45:42
#
#                                        voltage_battery  \
# 1    [4.191491807505295, 4.190749067776103, 3.97487...
# 3    [4.189773213846608, 4.188881380279099, 3.97915...
# 5    [4.188186735991303, 4.187198338393574, 3.97999...
# 7    [4.188461118855572, 4.187752210174129, 3.98161...
# 9    [4.188298524761055, 4.187384730878918, 3.98225...
# ..                                                 ...
# 599  [4.196640912532072, 4.195891409328115, 3.97041...
# 603  [4.195623574912322, 4.195225391012888, 3.96944...
# 607  [4.195862008850563, 4.195180368506587, 3.96948...
# 611  [4.18482689434833, 4.184358228897457, 3.964730...
# 613  [4.201968615940368, 4.200942039471311, 3.98225...
#
#                                        current_battery  \
# 1    [-0.004901589207462, -0.0014780055516420002, -...
# 3    [2.1251179810807652e-05, -0.00087947126634, -2...
# 5    [-0.0017540301662320001, -0.001791647748693000...
# 7    [-0.002775036129446, 0.00023371270769300003, -...
# 9    [-0.007980866803888001, 0.0017014548245030002,...
# ..                                                 ...
# 599  [-0.0031723450500130003, -0.001165548113920000...
# 603  [-0.005227006197317001, -0.0018109194843490002...
# 607  [-0.0005545264293170001, 0.001394789927994, -2...
# 611  [-0.0038126960802460003, -0.003553288376752, -...
# 613  [-0.000856557979434, -0.0011276212441780002, -...
#
#                                           temp_battery  \
# 1    [24.330033885570543, 24.325993424022467, 24.38...
# 3    [24.697751935729325, 24.685948163596, 24.73813...
# 5    [24.734266163954402, 24.74050014862512, 24.791...
# 7    [24.65423646922845, 24.652243741292516, 24.697...
# 9    [24.524796959348127, 24.518700434435164, 24.57...
# ..                                                 ...
# 599  [23.741424141669572, 23.73611267134457, 23.762...
# 603  [23.80397851847974, 23.80026564355092, 23.8387...
# 607  [23.849121770252687, 23.85032548167981, 23.872...
# 611  [24.93410482186201, 24.92195746617458, 24.9390...
# 613  [25.09329713312876, 25.10437816806932, 25.1061...
#
#                                           current_load  \
# 1    [-0.0006000000000000001, -0.000600000000000000...
# 3    [-0.0006000000000000001, -0.000600000000000000...
# 5    [-0.0006000000000000001, -0.000600000000000000...
# 7    [-0.0006000000000000001, -0.000600000000000000...
# 9    [-0.0006000000000000001, -0.000600000000000000...
# ..                                                 ...
# 599  [0.0006000000000000001, 0.0006000000000000001,...
# 603  [0.0006000000000000001, 0.0006000000000000001,...
# 607  [0.0006000000000000001, 0.0006000000000000001,...
# 611  [0.0006000000000000001, 0.0006000000000000001,...
# 613  [0.0006000000000000001, 0.0006000000000000001,...
#
#                                           voltage_load  \
# 1    [0.0, 4.206, 3.062, 3.03, 3.011, 2.991, 2.977,...
# 3    [0.0, 4.204, 3.056, 3.024, 3.003, 2.983, 2.973...
# 5    [0.0, 4.203, 3.055, 3.023, 3.0, 2.981, 2.96999...
# 7    [0.0, 4.203, 3.055, 3.023, 2.999, 2.982, 2.969...
# 9    [0.0, 4.203, 3.056, 3.025, 3.0, 2.984, 2.973, ...
# ..                                                 ...
# 599  [0.0, 4.211, 2.944, 2.931, 2.92, 2.906, 2.894,...
# 603  [0.0, 4.211, 2.926, 2.93, 2.916, 2.902, 2.8890...
# 607  [0.0, 4.211, 2.939, 2.9290000000000003, 2.916,...
# 611  [0.0, 4.2, 2.977, 2.947, 2.931, 2.917, 2.90500...
# 613  [0.0, 4.217, 2.936, 2.941, 2.9290000000000003,...
#
#                                                   time              Capacity
# 1    [0.0, 16.781, 35.702999999999996, 53.781, 71.9...  [1.8564874208181572]
# 3    [0.0, 16.672, 35.703, 53.828, 71.891, 90.047, ...   [1.846327249719927]
# 5    [0.0, 16.796999999999997, 35.766, 53.891, 72.0...   [1.835349194223407]
# 7    [0.0, 16.766000000000002, 35.75, 53.813, 72.04...   [1.835262527582112]
# 9    [0.0, 16.719, 35.656000000000006, 53.859, 72.0...   [1.834645508212041]
# ..                                                 ...                   ...
# 599  [0.0, 9.343, 19.483999999999998, 28.7650000000...   [1.293463613844243]
# 603  [0.0, 9.359000000000002, 19.562000000000005, 2...   [1.288003392619118]
# 607  [0.0, 9.313000000000002, 19.469, 28.797, 38.14...    [1.28745252213794]
# 611  [0.0, 9.375, 19.593999999999998, 28.9839999999...   [1.309015364230735]
# 613  [0.0, 9.328, 19.515, 28.936999999999998, 38.31...   [1.325079328642935]
#
# [168 rows x 9 columns]

# %% [markdown]
# # Voltage versus Time plot

# %%
for i in data_f:
    plt.plot(data_f[i].loc['time'], data_f[i].loc['voltage_battery'])
    
plt.xlabel("time (sec)")
plt.ylabel("voltage (V)")
plt.title("Voltage vs Time")
# Out:
# Text(0.5, 1.0, 'Voltage vs Time')

# %% [markdown]
# # Model

# %%
def get_model_SimpleRNN(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = keras.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=input_shape),
        keras.layers.SimpleRNN(20, return_sequences=True),
        keras.layers.TimeDistributed(keras.layers.Dense(window_length))
    ])

    return model

def get_model_GRU(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = keras.Sequential([
        keras.layers.GRU(20, return_sequences=True, input_shape=input_shape),
        keras.layers.GRU(20, return_sequences=True),
        keras.layers.TimeDistributed(keras.layers.Dense(window_length))
    ])

    return model

def get_model_LSTM(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = keras.Sequential([
        keras.layers.LSTM(20, return_sequences=True, input_shape=input_shape),
        keras.layers.LSTM(20, return_sequences=True),
        keras.layers.TimeDistributed(keras.layers.Dense(window_length))
    ])

    return model

# %%
rnn_model_SimpleRNN = get_model_SimpleRNN([None, 1])
rnn_model_GRU = get_model_GRU([None, 1])
rnn_model_LSTM = get_model_LSTM([None, 1])

# %%
print("SimpleRNN:")
rnn_model_SimpleRNN.summary()
print("\nGRU:")
rnn_model_GRU.summary()
print("\nLSTM:")
rnn_model_LSTM.summary()
# Out:
# SimpleRNN:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, None, 20)          440
#
#  simple_rnn_1 (SimpleRNN)    (None, None, 20)          820
#
#  time_distributed (TimeDistr  (None, None, 1)          21
#  ibuted)
#
# =================================================================
# Total params: 1,281
# Trainable params: 1,281
# Non-trainable params: 0
# _________________________________________________________________
#
# GRU:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, None, 20)          1380
#
#  gru_1 (GRU)                 (None, None, 20)          2520
#
#  time_distributed_1 (TimeDis  (None, None, 1)          21
#  tributed)
#
# =================================================================
# Total params: 3,921
# Trainable params: 3,921
# Non-trainable params: 0
# _________________________________________________________________
#
# LSTM:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 20)          1760
#
#  lstm_1 (LSTM)               (None, None, 20)          3280
#
#  time_distributed_2 (TimeDis  (None, None, 1)          21
#  tributed)
#
# =================================================================
# Total params: 5,061
# Trainable params: 5,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with default settings), the cross-entropy loss function and
    accuracy as the only metric. 
    Your function doesn't need to return anything; the model will be compiled in-place.
    """
    
    model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'cosine_proximity'])
#     model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'cosine_proximity'])
    
    return model

# %%
simpleRNN_model = compile_model(rnn_model_SimpleRNN)
GRU_model = compile_model(rnn_model_GRU)
LSTM_model = compile_model(rnn_model_LSTM)

# %% [markdown]
# # Training

# %% [markdown]
# ## SimpleRNN

# %%
def train_model(model, train_seq, train_labels, epochs):
    return model.fit(train_seq, train_labels, epochs=epochs)

# %%
print(train_seq.shape)
history = train_model(simpleRNN_model, train_seq, y_train, 5)
# Out:
# (25113, 100, 1, 1)
# Epoch 1/5
# 785/785 [==============================] - 13s 15ms/step - loss: 0.3007 - mean_squared_error: 0.3007 - mean_absolute_error: 0.2330 - mean_absolute_percentage_error: 6.9818 - cosine_proximity: 0.9890
# Epoch 2/5
# 785/785 [==============================] - 12s 15ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 3.4270 - cosine_proximity: 1.0000
# Epoch 3/5
# 785/785 [==============================] - 11s 15ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - mean_absolute_error: 0.1029 - mean_absolute_percentage_error: 3.1581 - cosine_proximity: 1.0000
# Epoch 4/5
# 785/785 [==============================] - 11s 14ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0958 - mean_absolute_percentage_error: 2.9420 - cosine_proximity: 1.0000
# Epoch 5/5
# 417/785 [==============>...............] - ETA: 5s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0952 - mean_absolute_percentage_error: 2.9235 - cosine_proximity: 1.0000

# %%
frame = pd.DataFrame(history.history)

# %%
acc_plot = frame.plot(y="loss", title="Loss vs Epochs", legend=False)
acc_plot.set(xlabel="Epochs", ylabel="Loss")
# Out:
# [Text(0.5, 0, 'Epochs'), Text(0, 0.5, 'Loss')]

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 10))
plt.subplot(221)
plt.plot(history.history['mean_squared_error'])
plt.gca().set_title('mean_squared_error vs Epochs')

plt.subplot(222)
plt.plot(history.history['mean_absolute_error'])
plt.gca().set_title('mean_absolute_error vs Epochs')

plt.subplot(223)
plt.plot(history.history['mean_absolute_percentage_error'])
plt.gca().set_title('mean_absolute_percentage_error vs Epochs')

plt.subplot(224)
plt.plot(history.history['cosine_proximity'])
plt.gca().set_title('cosine_proximity vs Epochs')

plt.show()

# %% [markdown]
# ### Model Evauation

# %%
def evaluate_model(model, test_seq, y_test):
    """
    This function should evaluate the model on the scaled_test_images and test_labels. 
    Your function should return a tuple (test_loss, test_accuracy).
    """
    return model.evaluate(test_seq, y_test)

# %%
print(test_seq.shape)
print(y_test.shape)
print(y_train.shape)
print(train_seq.shape)
evaluate_model(simpleRNN_model, test_seq, y_test)
# Out:
# (8372, 100, 1)
# (8372, 1)
# (25113, 1, 1)
# (25113, 100, 1, 1)
# 262/262 [==============================] - 2s 8ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 3.3139 - cosine_proximity: 9.9992
# [0.023429250344634056,
#  0.023429250344634056,
#  0.10760650038719177,
#  3.3138632774353027,
#  9.999151229858398]

# %% [markdown]
# ## GRU

# %%
print(train_seq.shape)
history = train_model(GRU_model, train_seq, y_train, 5)
# Out:
# (25113, 100, 1, 1)
# Epoch 1/5
# 785/785 [==============================] - 54s 65ms/step - loss: 0.2353 - mean_squared_error: 0.2353 - mean_absolute_error: 0.2092 - mean_absolute_percentage_error: 6.2879 - cosine_proximity: 1.0000
# Epoch 2/5
# 785/785 [==============================] - 50s 64ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 3.4372 - cosine_proximity: 1.0000
# Epoch 3/5
# 785/785 [==============================] - 50s 64ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 3.2299 - cosine_proximity: 1.0000
# Epoch 4/5
# 785/785 [==============================] - 50s 64ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 3.0914 - cosine_proximity: 1.0000
# Epoch 5/5
# 785/785 [==============================] - 51s 65ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0989 - mean_absolute_percentage_error: 3.0379 - cosine_proximity: 1.0000

# %%
frame = pd.DataFrame(history.history)

# %%
acc_plot = frame.plot(y="loss", title="Loss vs Epochs", legend=False)
acc_plot.set(xlabel="Epochs", ylabel="Loss")
# Out:
# [Text(0.5, 0, 'Epochs'), Text(0, 0.5, 'Loss')]

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 10))
plt.subplot(221)
plt.plot(history.history['mean_squared_error'])
plt.gca().set_title('mean_squared_error')

plt.subplot(222)
plt.plot(history.history['mean_absolute_error'])
plt.gca().set_title('mean_absolute_error')

plt.subplot(223)
plt.plot(history.history['mean_absolute_percentage_error'])
plt.gca().set_title('mean_absolute_percentage_error')

plt.subplot(224)
plt.plot(history.history['cosine_proximity'])
plt.gca().set_title('cosine_proximity')

plt.show()

# %% [markdown]
# ### Model Evauation

# %%
def evaluate_model(model, test_seq, y_test):
    """
    This function should evaluate the model on the scaled_test_images and test_labels. 
    Your function should return a tuple (test_loss, test_accuracy).
    """
    return model.evaluate(test_seq, y_test)

# %%
evaluate_model(GRU_model, test_seq, y_test)
# Out:
# 262/262 [==============================] - 5s 17ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0970 - mean_absolute_percentage_error: 2.9682 - cosine_proximity: 9.9992
# [0.022247521206736565,
#  0.022247521206736565,
#  0.0969669297337532,
#  2.968223810195923,
#  9.99920654296875]

# %% [markdown]
# ## LSTM

# %%
print(train_seq.shape)
history = train_model(LSTM_model, train_seq, y_train, 5)
# Out:
# (25113, 100, 1, 1)
# Epoch 1/5
# 785/785 [==============================] - 40s 47ms/step - loss: 0.3672 - mean_squared_error: 0.3672 - mean_absolute_error: 0.2592 - mean_absolute_percentage_error: 7.7712 - cosine_proximity: 0.9971
# Epoch 2/5
# 785/785 [==============================] - 35s 45ms/step - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1209 - mean_absolute_percentage_error: 3.6906 - cosine_proximity: 1.0000
# Epoch 3/5
# 785/785 [==============================] - 35s 45ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - mean_absolute_error: 0.0964 - mean_absolute_percentage_error: 2.9589 - cosine_proximity: 1.0000
# Epoch 4/5
# 785/785 [==============================] - 35s 44ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - mean_absolute_error: 0.0912 - mean_absolute_percentage_error: 2.8036 - cosine_proximity: 1.0000
# Epoch 5/5
# 785/785 [==============================] - 35s 45ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - mean_absolute_error: 0.0889 - mean_absolute_percentage_error: 2.7368 - cosine_proximity: 1.0000

# %%
frame = pd.DataFrame(history.history)

# %%
acc_plot = frame.plot(y="loss", title="Loss vs Epochs", legend=False)
acc_plot.set(xlabel="Epochs", ylabel="Loss")
# Out:
# [Text(0.5, 0, 'Epochs'), Text(0, 0.5, 'Loss')]

# %%
fig, axs = plt.subplots(2, 2, figsize=(13, 10))
plt.subplot(221)
plt.plot(history.history['mean_squared_error'])
plt.gca().set_title('mean_squared_error')

plt.subplot(222)
plt.plot(history.history['mean_absolute_error'])
plt.gca().set_title('mean_absolute_error')

plt.subplot(223)
plt.plot(history.history['mean_absolute_percentage_error'])
plt.gca().set_title('mean_absolute_percentage_error')

plt.subplot(224)
plt.plot(history.history['cosine_proximity'])
plt.gca().set_title('cosine_proximity')

plt.show()

# %% [markdown]
# ### Model Evauation

# %%
def evaluate_model(model, test_seq, y_test):
    """
    This function should evaluate the model on the scaled_test_images and test_labels. 
    Your function should return a tuple (test_loss, test_accuracy).
    """
    return model.evaluate(test_seq, y_test)

# %%
evaluate_model(LSTM_model, test_seq, y_test)
# Out:
# 262/262 [==============================] - 4s 14ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - mean_absolute_error: 0.0877 - mean_absolute_percentage_error: 2.6805 - cosine_proximity: 9.9996
# [0.019213581457734108,
#  0.019213581457734108,
#  0.08774234354496002,
#  2.680466413497925,
#  9.999581336975098]

# %% [markdown]
# # Estimating The Capacity

# %% [markdown]
# ## Using RNN

# %%
lst_flag = []
for i in data_f.loc["voltage_battery"]:
    lst_flag.append(len(i))
min_num_voltage = min(lst_flag)

voltage = [v for v in data_f.loc["voltage_battery"]]
voltage = [voltage[i][:min_num_voltage] for i in range(len(voltage))]
voltage = np.array(voltage)
capacity = np.array(capacity)
print(voltage.shape)
print(capacity.shape)
print(type(voltage))
print(type(capacity))
# Out:
# (168, 179)
# (168, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
voltage = voltage[...,np.newaxis]

print(voltage.shape)
print(capacity.shape)
# Out:
# (168, 179, 1)
# (168, 1)

# %%
train_seq_cap, test_seq_cap, y_train_cap, y_test_cap = train_test_split(voltage, capacity, test_size=0.25)

# %%
model_cap = keras.Sequential([
    keras.layers.LSTM(50, activation="tanh", return_sequences=False, input_shape=(min_num_voltage,1)),
    keras.layers.Dense(1)
])

# %%
model_cap = compile_model(model_cap)
history_cap = train_model(model_cap, train_seq_cap, y_train_cap, 50)

frame = pd.DataFrame(history_cap.history)
acc_plot = frame.plot(y="loss", title="Loss vs Epochs", legend=False)
acc_plot.set(xlabel="Epochs", ylabel="Loss", title="Loss History for LSTM")
plt.show()

evaluate_model(model_cap, test_seq_cap, y_test_cap)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 2s 47ms/step - loss: 3.5998 - mean_squared_error: 3.5998 - mean_absolute_error: 1.8833 - mean_absolute_percentage_error: 119.4748 - cosine_proximity: -1.0000
# Epoch 2/50
# 4/4 [==============================] - 0s 47ms/step - loss: 1.8924 - mean_squared_error: 1.8924 - mean_absolute_error: 1.3534 - mean_absolute_percentage_error: 85.3019 - cosine_proximity: 1.0000
# Epoch 3/50
# 4/4 [==============================] - 0s 45ms/step - loss: 0.7667 - mean_squared_error: 0.7667 - mean_absolute_error: 0.8427 - mean_absolute_percentage_error: 52.5814 - cosine_proximity: 1.0000
# Epoch 4/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1925 - mean_squared_error: 0.1925 - mean_absolute_error: 0.3756 - mean_absolute_percentage_error: 22.6308 - cosine_proximity: 1.0000
# Epoch 5/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0487 - mean_squared_error: 0.0487 - mean_absolute_error: 0.1905 - mean_absolute_percentage_error: 12.4161 - cosine_proximity: 1.0000
# Epoch 6/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1141 - mean_squared_error: 0.1141 - mean_absolute_error: 0.2793 - mean_absolute_percentage_error: 19.3645 - cosine_proximity: 1.0000
# Epoch 7/50
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1407 - mean_squared_error: 0.1407 - mean_absolute_error: 0.3238 - mean_absolute_percentage_error: 22.2394 - cosine_proximity: 1.0000
# Epoch 8/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0957 - mean_squared_error: 0.0957 - mean_absolute_error: 0.2493 - mean_absolute_percentage_error: 17.3995 - cosine_proximity: 1.0000
# Epoch 9/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1905 - mean_absolute_percentage_error: 13.1078 - cosine_proximity: 1.0000
# Epoch 10/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0367 - mean_squared_error: 0.0367 - mean_absolute_error: 0.1720 - mean_absolute_percentage_error: 11.1927 - cosine_proximity: 1.0000
# Epoch 11/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - mean_absolute_error: 0.1752 - mean_absolute_percentage_error: 10.9041 - cosine_proximity: 1.0000
# Epoch 12/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0439 - mean_squared_error: 0.0439 - mean_absolute_error: 0.1801 - mean_absolute_percentage_error: 10.9948 - cosine_proximity: 1.0000
# Epoch 13/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0435 - mean_squared_error: 0.0435 - mean_absolute_error: 0.1795 - mean_absolute_percentage_error: 10.9688 - cosine_proximity: 1.0000
# Epoch 14/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0397 - mean_squared_error: 0.0397 - mean_absolute_error: 0.1743 - mean_absolute_percentage_error: 10.8009 - cosine_proximity: 1.0000
# Epoch 15/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - mean_absolute_error: 0.1696 - mean_absolute_percentage_error: 10.7316 - cosine_proximity: 1.0000
# Epoch 16/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - mean_absolute_error: 0.1706 - mean_absolute_percentage_error: 11.0191 - cosine_proximity: 1.0000
# Epoch 17/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - mean_absolute_error: 0.1694 - mean_absolute_percentage_error: 11.0875 - cosine_proximity: 1.0000
# Epoch 18/50
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - mean_absolute_error: 0.1701 - mean_absolute_percentage_error: 11.1749 - cosine_proximity: 1.0000
# Epoch 19/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - mean_absolute_error: 0.1697 - mean_absolute_percentage_error: 11.1225 - cosine_proximity: 1.0000
# Epoch 20/50
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - mean_absolute_error: 0.1686 - mean_absolute_percentage_error: 10.9911 - cosine_proximity: 1.0000
# Epoch 21/50
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - mean_absolute_error: 0.1685 - mean_absolute_percentage_error: 10.8948 - cosine_proximity: 1.0000
# Epoch 22/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - mean_absolute_error: 0.1680 - mean_absolute_percentage_error: 10.7963 - cosine_proximity: 1.0000
# Epoch 23/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - mean_absolute_error: 0.1680 - mean_absolute_percentage_error: 10.7701 - cosine_proximity: 1.0000
# Epoch 24/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - mean_absolute_error: 0.1682 - mean_absolute_percentage_error: 10.7994 - cosine_proximity: 1.0000
# Epoch 25/50
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0348 - mean_squared_error: 0.0348 - mean_absolute_error: 0.1678 - mean_absolute_percentage_error: 10.8066 - cosine_proximity: 1.0000
# Epoch 26/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0348 - mean_squared_error: 0.0348 - mean_absolute_error: 0.1679 - mean_absolute_percentage_error: 10.8413 - cosine_proximity: 1.0000
# Epoch 27/50
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0347 - mean_squared_error: 0.0347 - mean_absolute_error: 0.1677 - mean_absolute_percentage_error: 10.8416 - cosine_proximity: 1.0000
# Epoch 28/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0347 - mean_squared_error: 0.0347 - mean_absolute_error: 0.1678 - mean_absolute_percentage_error: 10.8502 - cosine_proximity: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - mean_absolute_error: 0.1676 - mean_absolute_percentage_error: 10.8477 - cosine_proximity: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - mean_absolute_error: 0.1674 - mean_absolute_percentage_error: 10.8200 - cosine_proximity: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0347 - mean_squared_error: 0.0347 - mean_absolute_error: 0.1675 - mean_absolute_percentage_error: 10.7958 - cosine_proximity: 1.0000
# Epoch 32/50
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - mean_absolute_error: 0.1675 - mean_absolute_percentage_error: 10.7931 - cosine_proximity: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0345 - mean_squared_error: 0.0345 - mean_absolute_error: 0.1672 - mean_absolute_percentage_error: 10.8037 - cosine_proximity: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0345 - mean_squared_error: 0.0345 - mean_absolute_error: 0.1672 - mean_absolute_percentage_error: 10.8125 - cosine_proximity: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0344 - mean_squared_error: 0.0344 - mean_absolute_error: 0.1670 - mean_absolute_percentage_error: 10.7946 - cosine_proximity: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - mean_absolute_error: 0.1668 - mean_absolute_percentage_error: 10.7668 - cosine_proximity: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - mean_absolute_error: 0.1666 - mean_absolute_percentage_error: 10.7546 - cosine_proximity: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - mean_absolute_error: 0.1666 - mean_absolute_percentage_error: 10.7446 - cosine_proximity: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0342 - mean_squared_error: 0.0342 - mean_absolute_error: 0.1667 - mean_absolute_percentage_error: 10.7615 - cosine_proximity: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1664 - mean_absolute_percentage_error: 10.7547 - cosine_proximity: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1663 - mean_absolute_percentage_error: 10.7542 - cosine_proximity: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1663 - mean_absolute_percentage_error: 10.7447 - cosine_proximity: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - mean_absolute_error: 0.1661 - mean_absolute_percentage_error: 10.7205 - cosine_proximity: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - mean_absolute_error: 0.1660 - mean_absolute_percentage_error: 10.7050 - cosine_proximity: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - mean_absolute_error: 0.1659 - mean_absolute_percentage_error: 10.7213 - cosine_proximity: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - mean_absolute_error: 0.1659 - mean_absolute_percentage_error: 10.7476 - cosine_proximity: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - mean_absolute_error: 0.1658 - mean_absolute_percentage_error: 10.7436 - cosine_proximity: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0338 - mean_squared_error: 0.0338 - mean_absolute_error: 0.1657 - mean_absolute_percentage_error: 10.7312 - cosine_proximity: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - mean_absolute_error: 0.1657 - mean_absolute_percentage_error: 10.7135 - cosine_proximity: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0337 - mean_squared_error: 0.0337 - mean_absolute_error: 0.1654 - mean_absolute_percentage_error: 10.6706 - cosine_proximity: 1.0000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - mean_absolute_error: 0.1723 - mean_absolute_percentage_error: 11.4461 - cosine_proximity: 1.0000
# [0.03601822257041931,
#  0.03601822257041931,
#  0.1723497211933136,
#  11.446128845214844,
#  0.9999998807907104]

# %%
# Estimation of SOH
predicted_cap = model_cap.predict(voltage)
initial_cap = capacity[0]
SOH_pred = predicted_cap / initial_cap * 100
SOH_real = capacity / initial_cap * 100
plt.plot(SOH_pred)
plt.plot(SOH_real)
plt.xlabel("Cycle")
plt.ylabel("SOH")
plt.title("Estimation of SOH Using LSTM")
# Out:
# 6/6 [==============================] - 0s 17ms/step
# Text(0.5, 1.0, 'Estimation of SOH Using LSTM')

# %% [markdown]
# ## Using MLP

# %%
model_MLP = keras.Sequential([
    keras.layers.Dense(32, activation="relu", input_shape=(min_num_voltage,)),
    keras.layers.Dense(64,activation="relu"),
    keras.layers.Dense(128,activation="relu"),
#     keras.layers.Dense(1, activation="softmax")
    keras.layers.Dense(1)
    
])

# %%
model_cap_MLP = compile_model(model_MLP)
history_cap = train_model(model_MLP, train_seq_cap, y_train_cap, 50)
frame = pd.DataFrame(history_cap.history)
acc_plot = frame.plot(y="loss", title="Loss vs Epochs", legend=False)
acc_plot.set(xlabel="Epochs", ylabel="Loss", title="Loss History for LSTM")
plt.show()
evaluate_model(model_cap, test_seq_cap, y_test_cap)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3699 - mean_squared_error: 1.3699 - mean_absolute_error: 0.9384 - mean_absolute_percentage_error: 60.6242 - cosine_proximity: 0.4921
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - mean_absolute_error: 0.3900 - mean_absolute_percentage_error: 25.6677 - cosine_proximity: 1.0000
# Epoch 3/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1675 - mean_squared_error: 0.1675 - mean_absolute_error: 0.3612 - mean_absolute_percentage_error: 21.8062 - cosine_proximity: 1.0000
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0788 - mean_squared_error: 0.0788 - mean_absolute_error: 0.2285 - mean_absolute_percentage_error: 15.5930 - cosine_proximity: 1.0000
# Epoch 5/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0590 - mean_squared_error: 0.0590 - mean_absolute_error: 0.2017 - mean_absolute_percentage_error: 13.2259 - cosine_proximity: 1.0000
# Epoch 6/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0597 - mean_squared_error: 0.0597 - mean_absolute_error: 0.1996 - mean_absolute_percentage_error: 11.8989 - cosine_proximity: 1.0000
# Epoch 7/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - mean_absolute_error: 0.1658 - mean_absolute_percentage_error: 11.1907 - cosine_proximity: 1.0000
# Epoch 8/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0325 - mean_squared_error: 0.0325 - mean_absolute_error: 0.1602 - mean_absolute_percentage_error: 10.4922 - cosine_proximity: 1.0000
# Epoch 9/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1576 - mean_absolute_percentage_error: 9.6772 - cosine_proximity: 1.0000
# Epoch 10/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0365 - mean_squared_error: 0.0365 - mean_absolute_error: 0.1682 - mean_absolute_percentage_error: 11.2553 - cosine_proximity: 1.0000
# Epoch 11/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - mean_absolute_error: 0.1469 - mean_absolute_percentage_error: 9.4040 - cosine_proximity: 1.0000
# Epoch 12/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0312 - mean_squared_error: 0.0312 - mean_absolute_error: 0.1569 - mean_absolute_percentage_error: 9.8790 - cosine_proximity: 1.0000
# Epoch 13/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1543 - mean_absolute_percentage_error: 10.0043 - cosine_proximity: 1.0000
# Epoch 14/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - mean_absolute_error: 0.1532 - mean_absolute_percentage_error: 10.0083 - cosine_proximity: 1.0000
# Epoch 15/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - mean_absolute_error: 0.1507 - mean_absolute_percentage_error: 9.6504 - cosine_proximity: 1.0000
# Epoch 16/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - mean_absolute_error: 0.1514 - mean_absolute_percentage_error: 9.7964 - cosine_proximity: 1.0000
# Epoch 17/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - mean_absolute_error: 0.1512 - mean_absolute_percentage_error: 9.7851 - cosine_proximity: 1.0000
# Epoch 18/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - mean_absolute_error: 0.1503 - mean_absolute_percentage_error: 9.6033 - cosine_proximity: 1.0000
# Epoch 19/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - mean_absolute_error: 0.1498 - mean_absolute_percentage_error: 9.5605 - cosine_proximity: 1.0000
# Epoch 20/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - mean_absolute_error: 0.1524 - mean_absolute_percentage_error: 9.9731 - cosine_proximity: 1.0000
# Epoch 21/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - mean_absolute_error: 0.1505 - mean_absolute_percentage_error: 9.7237 - cosine_proximity: 1.0000
# Epoch 22/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - mean_absolute_error: 0.1494 - mean_absolute_percentage_error: 9.5871 - cosine_proximity: 1.0000
# Epoch 23/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0274 - mean_squared_error: 0.0274 - mean_absolute_error: 0.1489 - mean_absolute_percentage_error: 9.6531 - cosine_proximity: 1.0000
# Epoch 24/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - mean_absolute_error: 0.1506 - mean_absolute_percentage_error: 9.6512 - cosine_proximity: 1.0000
# Epoch 25/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - mean_absolute_error: 0.1514 - mean_absolute_percentage_error: 9.9230 - cosine_proximity: 1.0000
# Epoch 26/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - mean_absolute_error: 0.1481 - mean_absolute_percentage_error: 9.3354 - cosine_proximity: 1.0000
# Epoch 27/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1533 - mean_absolute_percentage_error: 10.0952 - cosine_proximity: 1.0000
# Epoch 28/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - mean_absolute_error: 0.1523 - mean_absolute_percentage_error: 9.8517 - cosine_proximity: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - mean_absolute_error: 0.1493 - mean_absolute_percentage_error: 9.5104 - cosine_proximity: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - mean_absolute_error: 0.1518 - mean_absolute_percentage_error: 9.8723 - cosine_proximity: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1462 - mean_absolute_percentage_error: 9.4076 - cosine_proximity: 1.0000
# Epoch 32/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - mean_absolute_error: 0.1507 - mean_absolute_percentage_error: 9.7281 - cosine_proximity: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1457 - mean_absolute_percentage_error: 9.4883 - cosine_proximity: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1453 - mean_absolute_percentage_error: 9.3600 - cosine_proximity: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - mean_absolute_error: 0.1456 - mean_absolute_percentage_error: 9.3979 - cosine_proximity: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1456 - mean_absolute_percentage_error: 9.4688 - cosine_proximity: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - mean_absolute_error: 0.1487 - mean_absolute_percentage_error: 9.6216 - cosine_proximity: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - mean_absolute_error: 0.1581 - mean_absolute_percentage_error: 9.9404 - cosine_proximity: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1526 - mean_absolute_percentage_error: 10.0791 - cosine_proximity: 1.0000
# Epoch 40/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - mean_absolute_error: 0.1493 - mean_absolute_percentage_error: 9.6160 - cosine_proximity: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1463 - mean_absolute_percentage_error: 9.4440 - cosine_proximity: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1469 - mean_absolute_percentage_error: 9.4539 - cosine_proximity: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0258 - mean_squared_error: 0.0258 - mean_absolute_error: 0.1457 - mean_absolute_percentage_error: 9.3805 - cosine_proximity: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1459 - mean_absolute_percentage_error: 9.4846 - cosine_proximity: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1443 - mean_absolute_percentage_error: 9.1813 - cosine_proximity: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - mean_absolute_error: 0.1510 - mean_absolute_percentage_error: 9.9900 - cosine_proximity: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - mean_absolute_error: 0.1513 - mean_absolute_percentage_error: 9.5110 - cosine_proximity: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - mean_absolute_error: 0.1465 - mean_absolute_percentage_error: 9.5803 - cosine_proximity: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - mean_absolute_error: 0.1420 - mean_absolute_percentage_error: 9.1744 - cosine_proximity: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - mean_absolute_error: 0.1538 - mean_absolute_percentage_error: 9.7356 - cosine_proximity: 1.0000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - mean_absolute_error: 0.1723 - mean_absolute_percentage_error: 11.4461 - cosine_proximity: 1.0000
# [0.03601822257041931,
#  0.03601822257041931,
#  0.1723497211933136,
#  11.446128845214844,
#  0.9999998807907104]

# %%
# Estimation of SOH
predicted_cap_MLP = model_cap_MLP.predict(voltage)
initial_cap_MLP = capacity[0]
SOH_pred_MLP = predicted_cap / initial_cap * 100
SOH_real_MLP = capacity / initial_cap * 100
plt.plot(SOH_pred)
plt.plot(SOH_real)
plt.xlabel("Cycle")
plt.ylabel("SOH")
plt.title("Estimation of SOH Using MLP")


SOH_pred.shape
# SOH_real.shape
# Out:
# 6/6 [==============================] - 0s 1ms/step
# (168, 1)
